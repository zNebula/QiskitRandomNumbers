# %%
# !pip install qiskit qiskit-aer qiskit[visualization] qiskit-ibm-runtime
# Out:
# Requirement already satisfied: qiskit in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.3.0)
# Requirement already satisfied: qiskit-aer in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.17.2)
# Requirement already satisfied: qiskit-ibm-runtime in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.45.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit) (2.4.3)
# Requirement already satisfied: scipy>=1.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit) (1.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit) (5.7.0)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.12/site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: psutil>=5 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit-aer) (7.1.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit[visualization]) (3.10.8)
# Requirement already satisfied: pydot in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit[visualization]) (4.0.1)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit[visualization]) (12.1.1)
# Requirement already satisfied: pylatexenc>=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit[visualization]) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit[visualization]) (0.13.2)
# Requirement already satisfied: sympy>=1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit[visualization]) (1.14.0)
# Requirement already satisfied: requests!=2.32.2,>=2.19 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (2.32.5)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (2.5.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit-ibm-runtime) (0.74.0)
# Requirement already satisfied: pydantic>=2.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit-ibm-runtime) (2.12.5)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from qiskit-ibm-runtime) (25.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.24.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.12.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (2025.11.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (46.0.5)
# Requirement already satisfied: pyspnego>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.1)
# Requirement already satisfied: cffi>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.23)
# Requirement already satisfied: pandas>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn>=0.9.0->qiskit[visualization]) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sympy>=1.3->qiskit[visualization]) (1.3.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.visualization import plot_histogram
from itertools import islice

# %%
# Initializing the backend
service = QiskitRuntimeService()

# https://quantum.cloud.ibm.com/docs/en/guides/hello-world
# https://cloud.ibm.com/iam/apikeys?bss_account=952fc7dad0544862a921fee4630e8563
# Out:
# ---------------------------------------------------------------------------
# AccountNotFoundError                      Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Initializing the backend
# ----> 2 service = QiskitRuntimeService()
#       4 # https://quantum.cloud.ibm.com/docs/en/guides/hello-world
#       5 # https://cloud.ibm.com/iam/apikeys?bss_account=952fc7dad0544862a921fee4630e8563
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:204, in QiskitRuntimeService.__init__(self, channel, token, url, filename, name, instance, proxies, verify, private_endpoint, url_resolver, region, plans_preference, tags)
#     202 self._all_instances: list[dict[str, Any]] = []
#     203 self._saved_instances: list[str] = []
# --> 204 self._account = self._discover_account(
#     205     token=token,
#     206     url=url,
#     207     instance=instance,
#     208     channel=channel,
#     209     filename=filename,
#     210     name=name,
#     211     proxies=ProxyConfiguration(**proxies) if proxies else None,
#     212     verify=verify,
#     213 )
#     215 if private_endpoint is not None:
#     216     self._account.private_endpoint = private_endpoint
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:436, in QiskitRuntimeService._discover_account(self, token, url, instance, channel, filename, name, proxies, verify)
#     434 # channel is not defined yet, get it from the AccountManager
#     435 if account is None:
# --> 436     account = AccountManager.get(filename=filename)
#     437 if instance:
#     438     account.instance = instance
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/qiskit_ibm_runtime/accounts/management.py:213, in AccountManager.get(cls, filename, name, channel)
#     210     if account_name in all_config:
#     211         return Account.from_saved_format(all_config[account_name])
# --> 213 raise AccountNotFoundError(
#     214     "Unable to find account. Please make sure an account with the channel name "
#     215     f"'{channel_}' is saved."
#     216 )
#
# AccountNotFoundError: "Unable to find account. Please make sure an account with the channel name 'ibm_quantum_platform' is saved."

# %%
# Fake
from qiskit.primitives import StatevectorSampler
sampler = StatevectorSampler()

# %%
# Real
'''
from qiskit_ibm_runtime import SamplerV2 as Sampler
# Select a real backend
backend = service.least_busy(simulator=False, operational=True)
sampler = Sampler(backend)
'''

# %%
backend = service.least_busy(operational=True, simulator=True)
backend.name

# %%
# Initialize quantum circuit with one qubit and one classical bit
circ = QuantumCircuit(1, 1)

# Apply Hadamard gate to qubit at the index 0
circ.h(0)

# Measure the qubit at index 0 and store in the classical bit at index 0
circ.measure(0,0)

# %%
# Draw the quantum circuit using matplotlib
circ.draw("mpl")

# %%
print("Details of Classical Register: ", circ.cregs)
# Details of Classical Register:  [ClassicalRegister(1, 'c')]

print("Details of Quantum Register: ", circ.qregs)
# Details of Quantum Register:  [QuantumRegister(1, 'q')]

# %%
# Transpile 
circ = transpile(circ, backend)

# %%
# Run the simulator 640000 times to generate 1000 64-bit number
result = backend.run(circ, shots=64*10000, memory=True).result()

# Extract the results from memory in a list and print them
memory = result.get_memory(circ)
# print(memory)

# %%
# Get the data of our experiment
counts = result.get_counts(circ)

# Plot the data in a histogram
plot_histogram(counts, title='Quantum Random Bit Distribution')

# %%
a = memory  
n = 64  

it = iter(a) 
res = [str(int(''.join((islice(it, n))) , 2)) for _ in range((len(a) + n - 1) // n)]
print(len(res))

# %%
with open("fake.txt", "w") as f:
    f.write("\n".join(res))
